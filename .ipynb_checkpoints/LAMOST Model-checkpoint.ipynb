# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
import warnings
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import timeit
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('input/LAMOST_final.csv')

# %%
df = df.dropna()
df
# Out:
#            obsid          ra        dec  redshift   class   mag1   mag2  \
# 0         210198   43.088799  -1.577594 -0.000038    STAR  19.75  17.54
# 2         106084  334.003910  -0.001640  0.123472  GALAXY  19.74  18.54
# 3        8204141   12.417300   2.166760  0.109395  GALAXY  19.76  18.54
# 4       43111178  208.960390   4.183370  0.174657  GALAXY  19.31  18.25
# 5        8202185   11.020312   1.561901  0.428038     QSO  16.87  16.68
# ...          ...         ...        ...       ...     ...    ...    ...
# 29994    8305163   50.820120   4.086140  1.296480     QSO  19.22  19.22
# 29996   67702208  323.729502   0.182460  3.288760     QSO  24.63  19.15
# 29997    8209182   13.833480   3.312840  0.082647  GALAXY  19.65  18.49
# 29998   21202172  121.822210   1.429060  0.094170  GALAXY  19.18  18.06
# 29999  134015009  153.834900  26.520243  2.026910     QSO  19.93  19.57
#
#         mag3   mag4   mag5
# 0      16.62  16.27  16.06
# 2      17.74  17.36  17.15
# 3      17.85  17.48  17.17
# 4      17.51  17.12  16.90
# 5      16.75  16.68  16.57
# ...      ...    ...    ...
# 29994  18.88  18.92  18.90
# 29996  18.82  18.74  18.68
# 29997  17.88  17.49  17.23
# 29998  17.53  17.20  17.01
# 29999  19.64  19.51  19.36
#
# [22510 rows x 10 columns]

# %%
df['redshift'] = df['redshift'].abs()

# %%
df['class'].value_counts()
# Out:
# QSO       9100
# GALAXY    8783
# STAR      4627
# Name: class, dtype: int64

# %%
df['class'].head(10)
ax = sns.countplot(x='class',data=df)

# %%
df[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#     class  redshift
# 2    STAR  0.000257
# 1     QSO  1.494844
# 0  GALAXY  0.125577

# %% [markdown]
# # Distance

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.cosmology import WMAP9 as cosmo

radec = SkyCoord(ra=df['ra']*u.degree, dec=df['dec']*u.degree, frame='icrs')
#radec.ra.value
#radec.dec.value
galactic = radec.galactic

df['l'] = galactic.l.value
df['b'] = galactic.b.value


r = cosmo.comoving_distance(df['redshift'])
df['distance']= r.value

df
# Out:
#            obsid          ra        dec  redshift   class   mag1   mag2  \
# 0         210198   43.088799  -1.577594  0.000038    STAR  19.75  17.54
# 2         106084  334.003910  -0.001640  0.123472  GALAXY  19.74  18.54
# 3        8204141   12.417300   2.166760  0.109395  GALAXY  19.76  18.54
# 4       43111178  208.960390   4.183370  0.174657  GALAXY  19.31  18.25
# 5        8202185   11.020312   1.561901  0.428038     QSO  16.87  16.68
# ...          ...         ...        ...       ...     ...    ...    ...
# 29994    8305163   50.820120   4.086140  1.296480     QSO  19.22  19.22
# 29996   67702208  323.729502   0.182460  3.288760     QSO  24.63  19.15
# 29997    8209182   13.833480   3.312840  0.082647  GALAXY  19.65  18.49
# 29998   21202172  121.822210   1.429060  0.094170  GALAXY  19.18  18.06
# 29999  134015009  153.834900  26.520243  2.026910     QSO  19.93  19.57
#
#         mag3   mag4   mag5           l          b     distance
# 0      16.62  16.27  16.06  176.658778 -51.373070     0.163475
# 2      17.74  17.36  17.15   62.440220 -43.873887   519.452928
# 3      17.85  17.48  17.17  122.028947 -60.701887   461.726465
# 4      17.51  17.12  16.90  339.563109  62.382657   726.030818
# 5      16.75  16.68  16.57  119.106811 -61.255197  1670.999141
# ...      ...    ...    ...         ...        ...          ...
# 29994  18.88  18.92  18.90  178.410967 -41.868331  4044.088957
# 29996  18.82  18.74  18.68   54.650118 -35.514182  6775.743979
# 29997  17.88  17.49  17.23  124.850579 -59.544393   350.963253
# 29998  17.53  17.20  17.01  220.519037  17.486813   398.850707
# 29999  19.64  19.51  19.36  204.807978  55.311768  5331.506932
#
# [22510 rows x 13 columns]

# %%
def cartesian(dist,alpha,delta):
    x = dist*np.cos(np.deg2rad(delta))*np.cos(np.deg2rad(alpha))
    y = dist*np.cos(np.deg2rad(delta))*np.sin(np.deg2rad(alpha))
    z = dist*np.sin(np.deg2rad(delta))
    return x,y,z

cart = cartesian(df['distance'],df['ra'],df['dec'])
df['x_coord'] = cart[0]
df['y_coord'] = cart[1]
df['z_coord'] = cart[2]

df.head()
# Out:
#       obsid          ra       dec  redshift   class   mag1   mag2   mag3  \
# 0    210198   43.088799 -1.577594  0.000038    STAR  19.75  17.54  16.62
# 2    106084  334.003910 -0.001640  0.123472  GALAXY  19.74  18.54  17.74
# 3   8204141   12.417300  2.166760  0.109395  GALAXY  19.76  18.54  17.85
# 4  43111178  208.960390  4.183370  0.174657  GALAXY  19.31  18.25  17.51
# 5   8202185   11.020312  1.561901  0.428038     QSO  16.87  16.68  16.75
#
#     mag4   mag5           l          b     distance      x_coord     y_coord  \
# 0  16.27  16.06  176.658778 -51.373070     0.163475     0.119340    0.111632
# 2  17.36  17.15   62.440220 -43.873887   519.452928   466.896737 -227.681314
# 3  17.48  17.17  122.028947 -60.701887   461.726465   450.603077   99.214154
# 4  17.12  16.90  339.563109  62.382657   726.030818  -633.551562 -350.611018
# 5  16.68  16.57  119.106811 -61.255197  1670.999141  1639.575651  319.304473
#
#      z_coord
# 0  -0.004501
# 2  -0.014869
# 3  17.456992
# 4  52.963023
# 5  45.546321

# %%
df['u-r'] = df['mag1']-df['mag4']

# %%
df = df.dropna()

# %%
df.head()
# Out:
#       obsid          ra       dec  redshift   class   mag1   mag2   mag3  \
# 0    210198   43.088799 -1.577594  0.000038    STAR  19.75  17.54  16.62
# 2    106084  334.003910 -0.001640  0.123472  GALAXY  19.74  18.54  17.74
# 3   8204141   12.417300  2.166760  0.109395  GALAXY  19.76  18.54  17.85
# 4  43111178  208.960390  4.183370  0.174657  GALAXY  19.31  18.25  17.51
# 5   8202185   11.020312  1.561901  0.428038     QSO  16.87  16.68  16.75
#
#     mag4   mag5           l          b     distance      x_coord     y_coord  \
# 0  16.27  16.06  176.658778 -51.373070     0.163475     0.119340    0.111632
# 2  17.36  17.15   62.440220 -43.873887   519.452928   466.896737 -227.681314
# 3  17.48  17.17  122.028947 -60.701887   461.726465   450.603077   99.214154
# 4  17.12  16.90  339.563109  62.382657   726.030818  -633.551562 -350.611018
# 5  16.68  16.57  119.106811 -61.255197  1670.999141  1639.575651  319.304473
#
#      z_coord   u-r
# 0  -0.004501  3.48
# 2  -0.014869  2.38
# 3  17.456992  2.28
# 4  52.963023  2.19
# 5  45.546321  0.19

# %%
df['class'] = df['class'].astype('category').cat.codes

# %%
df['class'].value_counts()
# Out:
# 1    9100
# 0    8783
# 2    4627
# Name: class, dtype: int64

# %%
df.columns
# Out:
# Index(['obsid', 'ra', 'dec', 'redshift', 'class', 'mag1', 'mag2', 'mag3',
#        'mag4', 'mag5', 'l', 'b', 'distance', 'x_coord', 'y_coord', 'z_coord',
#        'u-r'],
#       dtype='object')

# %%
df[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#    class  redshift
# 2      2  0.000257
# 1      1  1.494844
# 0      0  0.125577

# %%
X_df = df.drop(['obsid','class','l','b','x_coord','y_coord','z_coord',"distance",'u-r'], axis=1).values
y_df = df['class'].values

# %%
df.drop(['obsid','class','l','b','x_coord','y_coord','z_coord','u-r','distance'], axis=1)
# Out:
#                ra        dec  redshift   mag1   mag2   mag3   mag4   mag5
# 0       43.088799  -1.577594  0.000038  19.75  17.54  16.62  16.27  16.06
# 2      334.003910  -0.001640  0.123472  19.74  18.54  17.74  17.36  17.15
# 3       12.417300   2.166760  0.109395  19.76  18.54  17.85  17.48  17.17
# 4      208.960390   4.183370  0.174657  19.31  18.25  17.51  17.12  16.90
# 5       11.020312   1.561901  0.428038  16.87  16.68  16.75  16.68  16.57
# ...           ...        ...       ...    ...    ...    ...    ...    ...
# 29994   50.820120   4.086140  1.296480  19.22  19.22  18.88  18.92  18.90
# 29996  323.729502   0.182460  3.288760  24.63  19.15  18.82  18.74  18.68
# 29997   13.833480   3.312840  0.082647  19.65  18.49  17.88  17.49  17.23
# 29998  121.822210   1.429060  0.094170  19.18  18.06  17.53  17.20  17.01
# 29999  153.834900  26.520243  2.026910  19.93  19.57  19.64  19.51  19.36
#
# [22510 rows x 8 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.20, random_state=44, shuffle =True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
random_forest = RandomForestClassifier(n_estimators=200)

start_time_train = timeit.default_timer()
random_forest.fit(X_train, y_train)
upsampling_elapsed = timeit.default_timer() - start_time_train
print('Training time for RBF: ' + str(upsampling_elapsed))
# Out:
# Training time for RBF: 4.310389400008717

# %%
y_pred = random_forest.predict(X_test)

Test_acc_random_forest = round(random_forest.score(X_test, y_test) * 100, 3)
print("Accuracy of Random Forest ",Test_acc_random_forest)
# Out:
# Accuracy of Random Forest  99.489

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1764
#            1       0.99      0.99      0.99      1803
#            2       1.00      1.00      1.00       935
#
#     accuracy                           0.99      4502
#    macro avg       1.00      1.00      1.00      4502
# weighted avg       0.99      0.99      0.99      4502

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1752,   11,    1],
#        [  11, 1792,    0],
#        [   0,    0,  935]], dtype=int64)

# %% [markdown]
# # SDSS Test

# %%
df = pd.read_csv('Test/new_sdss.csv')

# %%
df.head()
# Out:
#           objID         ra       dec   run  rerun  camcol  field    type  \
# 0  1.240000e+18  15.502002  0.515352  4263    301       5    219    STAR
# 1  1.240000e+18  15.493380  0.513567  4263    301       5    219  GALAXY
# 2  1.240000e+18  15.493380  0.513567  4263    301       5    219  GALAXY
# 3  1.240000e+18  15.503910  0.512176  4263    301       5    219  GALAXY
# 4  1.240000e+18  15.491410  0.463359  4263    301       5    219  GALAXY
#
#           u         g         r         i         z     specObjID  plate  \
# 0  21.99938  19.73039  18.67928  18.26405  18.00196  1.690000e+18   1498
# 1  23.46245  21.21311  19.44700  18.82201  18.37411  7.800000e+17    693
# 2  23.46245  21.21311  19.44700  18.82201  18.37411  4.760000e+18   4225
# 3  19.15817  18.05311  17.63875  17.40735  17.27723  4.460000e+17    396
# 4  22.73320  20.98437  19.29221  18.63999  18.21168  7.800000e+17    693
#
#      mjd  fiberID  redshift
# 0  52914      388  0.000114
# 1  52254      503  0.373543
# 2  55455      808  0.373478
# 3  51816      435  0.018285
# 4  52254      489  0.390870

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.cosmology import WMAP9 as cosmo

radec = SkyCoord(ra=df['ra']*u.degree, dec=df['dec']*u.degree, frame='icrs')
#radec.ra.value
#radec.dec.value
galactic = radec.galactic

df['l'] = galactic.l.value
df['b'] = galactic.b.value


r = cosmo.comoving_distance(df['z'])
df['distance']= r.value

df.head()
# Out:
#           objID         ra       dec   run  rerun  camcol  field    type  \
# 0  1.240000e+18  15.502002  0.515352  4263    301       5    219    STAR
# 1  1.240000e+18  15.493380  0.513567  4263    301       5    219  GALAXY
# 2  1.240000e+18  15.493380  0.513567  4263    301       5    219  GALAXY
# 3  1.240000e+18  15.503910  0.512176  4263    301       5    219  GALAXY
# 4  1.240000e+18  15.491410  0.463359  4263    301       5    219  GALAXY
#
#           u         g  ...         i         z     specObjID  plate    mjd  \
# 0  21.99938  19.73039  ...  18.26405  18.00196  1.690000e+18   1498  52914
# 1  23.46245  21.21311  ...  18.82201  18.37411  7.800000e+17    693  52254
# 2  23.46245  21.21311  ...  18.82201  18.37411  4.760000e+18   4225  55455
# 3  19.15817  18.05311  ...  17.40735  17.27723  4.460000e+17    396  51816
# 4  22.73320  20.98437  ...  18.63999  18.21168  7.800000e+17    693  52254
#
#    fiberID  redshift           l          b      distance
# 0      388  0.000114  128.612405 -62.239757  10848.890220
# 1      503  0.373543  128.594303 -62.242293  10884.556761
# 2      808  0.373478  128.594303 -62.242293  10884.556761
# 3      435  0.018285  128.617087 -62.242753  10776.327021
# 4      489  0.390870  128.599566 -62.292480  10869.117288
#
# [5 rows x 21 columns]

# %%
df[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-224-38078c59be78> in <module>
# ----> 1 df[['redshift','type']].groupby(['type'],as_index=False).mean().sort_values(by='class',ascending=False)
#
# c:\users\swade\miniconda3\envs\project\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# c:\users\swade\miniconda3\envs\project\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'class'

# %%
def cartesian(dist,alpha,delta):
    x = dist*np.cos(np.deg2rad(delta))*np.cos(np.deg2rad(alpha))
    y = dist*np.cos(np.deg2rad(delta))*np.sin(np.deg2rad(alpha))
    z = dist*np.sin(np.deg2rad(delta))
    return x,y,z

cart = cartesian(df['distance'],df['ra'],df['dec'])
df['x_coord'] = cart[0]
df['y_coord'] = cart[1]
df['z_coord'] = cart[2]

df.head()
# Out:
#           objID         ra       dec   run  rerun  camcol  field    type  \
# 0  1.240000e+18  15.502002  0.515352  4263    301       5    219    STAR
# 1  1.240000e+18  15.493380  0.513567  4263    301       5    219  GALAXY
# 2  1.240000e+18  15.493380  0.513567  4263    301       5    219  GALAXY
# 3  1.240000e+18  15.503910  0.512176  4263    301       5    219  GALAXY
# 4  1.240000e+18  15.491410  0.463359  4263    301       5    219  GALAXY
#
#           u         g  ...  plate    mjd  fiberID  redshift           l  \
# 0  21.99938  19.73039  ...   1498  52914      388  0.000114  128.612405
# 1  23.46245  21.21311  ...    693  52254      503  0.373543  128.594303
# 2  23.46245  21.21311  ...   4225  55455      808  0.373478  128.594303
# 3  19.15817  18.05311  ...    396  51816      435  0.018285  128.617087
# 4  22.73320  20.98437  ...    693  52254      489  0.390870  128.599566
#
#            b      distance       x_coord      y_coord    z_coord
# 0 -62.239757  10848.890220  10453.796810  2899.487782  97.579989
# 1 -62.242293  10884.556761  10488.605023  2907.442565  97.561743
# 2 -62.242293  10884.556761  10488.605023  2907.442565  97.561743
# 3 -62.242753  10776.327021  10383.785450  2880.441689  96.329975
# 4 -62.292480  10869.117288  10473.905256  2902.980027  87.899211
#
# [5 rows x 24 columns]

# %%
df['u-r'] = df['u']-df['r']

# %%
df['class'] = df['class'].astype('category').cat.codes

# %%
df = df.dropna()
# obsid', 'ra', 'dec', 'redshift', 'class', 'mag1', 'mag2', 'mag3',
#        'mag4', 'mag5', 'l', 'b', 'distance', 'x_coord', 'y_coord', 'z_coord',
#        'u-r'

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid',
#        'l', 'b', 'distance', 'x_coord', 'y_coord', 'z_coord', 'u-r'],
#       dtype='object')

# %%
columns_titles = ['ra','dec',"redshift","u","g","i","r","z","class"]
data=df.reindex(columns=columns_titles)

# %%
data
# Out:
#               ra        dec  redshift         u         g         i         r  \
# 0     121.802126   0.855476  0.504717  25.02634  21.90814  19.22341  20.17926
# 1     121.748271   0.891010  0.579273  23.74677  22.75365  20.06169  21.10284
# 2     121.708487   0.874751  0.772647  23.15607  22.95075  19.71096  20.89328
# 3     121.820752   0.931990  0.101993  19.37035  17.34262  15.92400  16.35286
# 4     121.910430   0.896389  0.585733  23.42736  22.81119  19.14886  20.27570
# ...          ...        ...       ...       ...       ...       ...       ...
# 9995   26.140868  13.288978  0.198558  21.86942  19.33298  17.39773  17.92570
# 9996   26.203556  13.228457  0.000077  22.71311  20.22278  18.54982  19.01100
# 9997   26.117428  13.328545  2.798480  21.61434  20.18770  19.74266  19.92519
# 9998   26.177382  13.220591 -0.000004  21.70630  20.41759  19.43685  19.71272
# 9999   26.113594  13.282359 -0.000368  23.41291  21.86090  21.84837  21.73222
#
#              z  class
# 0     18.68446      0
# 1     19.50690      0
# 2     19.10471      0
# 3     15.58903      0
# 4     18.67588      0
# ...        ...    ...
# 9995  17.02359      0
# 9996  18.27419      2
# 9997  19.59234      1
# 9998  19.37791      2
# 9999  21.25142      2
#
# [9991 rows x 9 columns]

# %%
y_df = data['class']
X_df = data.loc[:, data.columns != 'class'].values

# %%
y_pred = random_forest.predict(X_df)

# %%
Test_acc_random_forest = round(random_forest.score(X_df, y_df) * 100, 3)
print("Accuracy of Random Forest ",Test_acc_random_forest)
# Out:
# Accuracy of Random Forest  63.457

# %%
print(classification_report(y_df, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.39      0.56      5926
#            1       0.25      0.98      0.40      1242
#            2       0.99      1.00      0.99      2823
#
#     accuracy                           0.63      9991
#    macro avg       0.74      0.79      0.65      9991
# weighted avg       0.90      0.63      0.66      9991

# %%
confusion_matrix(y_df, y_pred)
# Out:
# array([[2305, 3589,   32],
#        [  29, 1212,    1],
#        [   0,    0, 2823]], dtype=int64)
