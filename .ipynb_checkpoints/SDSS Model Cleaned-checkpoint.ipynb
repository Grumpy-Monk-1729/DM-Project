# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
import warnings
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, normalize 
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import timeit
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('input/SDSS_final_revised.csv')
sdss_df_fe = df

# %%
df.head()
# Out:
#           objid          ra        dec         u         g         r  \
# 0  1.237650e+18  180.171192  -0.443716  20.05391  19.26826  18.97941
# 1  1.237650e+18  148.720423   0.388818  19.71105  18.22643  17.47550
# 2  1.237650e+18  125.375682  46.923933  24.63465  25.11436  23.07034
# 3  1.237650e+18  127.419124  49.841883  26.02437  22.08174  21.07398
# 4  1.237650e+18  146.105413   0.517503  25.21094  23.02446  21.29774
#
#           i         z   run  rerun  camcol  field     specobjid  class  \
# 0  18.83350  18.78498   756    301       2    430  3.284330e+18      2
# 1  16.97291  16.67962   756    301       4    220  3.007790e+17      0
# 2  21.27211  19.68351  1331    301       3    146  8.250860e+18      2
# 3  20.18755  19.55985  1331    301       5    167  4.159110e+18      2
# 4  20.05228  19.42774  1239    301       5    172  4.307950e+18      0
#
#    redshift  plate    mjd  fiberid
# 0 -0.000231   2917  54556      280
# 1  0.094745    267  51608      595
# 2 -0.000051   7328  56715      949
# 3 -0.000080   3694  55209      120
# 4  0.625067   3826  55563      931

# %%
df['class'].value_counts()
# Out:
# 0    10000
# 1    10000
# 2    10000
# Name: class, dtype: int64

# %%
df['class'].head(10)
ax = sns.countplot(x='class',data=df)

# %%
df[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#    class  redshift
# 2      2  0.000082
# 1      1  1.913542
# 0      0  0.345878

# %%
df['class'].value_counts()
# Out:
# 0    10000
# 1    10000
# 2    10000
# Name: class, dtype: int64

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
df[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#    class  redshift
# 2      2  0.000082
# 1      1  1.913542
# 0      0  0.345878

# %%
sdss_df_fe = df.drop(['run','rerun','camcol','field','specobjid','mjd','fiberid','objid','plate'],axis=1)

# %%
sdss_df_fe
# Out:
#                ra        dec         u         g         r         i  \
# 0      180.171192  -0.443716  20.05391  19.26826  18.97941  18.83350
# 1      148.720423   0.388818  19.71105  18.22643  17.47550  16.97291
# 2      125.375682  46.923933  24.63465  25.11436  23.07034  21.27211
# 3      127.419124  49.841883  26.02437  22.08174  21.07398  20.18755
# 4      146.105413   0.517503  25.21094  23.02446  21.29774  20.05228
# ...           ...        ...       ...       ...       ...       ...
# 29995   23.528946  13.560824  21.97666  21.98527  21.08089  20.09739
# 29996  161.224715  -1.024612  25.25298  21.92094  20.09428  19.21824
# 29997  211.264527  -0.955070  21.08242  20.73010  20.72403  20.67605
# 29998  163.496017  -0.475936  20.10371  17.79990  16.71217  16.16045
# 29999  125.256104  46.892296  22.48249  20.68993  20.14574  19.97823
#
#               z  class  redshift
# 0      18.78498      2 -0.000231
# 1      16.67962      0  0.094745
# 2      19.68351      2 -0.000051
# 3      19.55985      2 -0.000080
# 4      19.42774      0  0.625067
# ...         ...    ...       ...
# 29995  19.80646      0  0.768351
# 29996  18.71379      0  0.482472
# 29997  20.30619      1  2.135831
# 29998  15.67794      0  0.072409
# 29999  20.01874      2 -0.000350
#
# [30000 rows x 9 columns]

# %%
scaler = MinMaxScaler()
sdss = scaler.fit_transform(sdss_df_fe.drop('class', axis=1))
X_train, X_test, y_train, y_test = train_test_split(sdss, sdss_df_fe['class'], test_size=0.33)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
random_forest = RandomForestClassifier(n_estimators=200)

start_time_train = timeit.default_timer()
random_forest.fit(X_train, y_train)
upsampling_elapsed = timeit.default_timer() - start_time_train
print('Training time for RBF: ' + str(upsampling_elapsed))
# Out:
# Training time for RBF: 7.141613299998426

# %%
y_pred = random_forest.predict(X_test)

Test_acc_random_forest = round(random_forest.score(X_test, y_test) * 100, 3)
print("Accuracy of Random Forest ",Test_acc_random_forest)
# Out:
# Accuracy of Random Forest  98.192

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      3286
#            1       0.98      0.96      0.97      3246
#            2       1.00      1.00      1.00      3368
#
#     accuracy                           0.98      9900
#    macro avg       0.98      0.98      0.98      9900
# weighted avg       0.98      0.98      0.98      9900

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[3227,   50,    9],
#        [ 120, 3126,    0],
#        [   0,    0, 3368]], dtype=int64)

# %% [markdown]
# # Lamost Test

# %%
df = pd.read_csv('Test/40879.csv')

# %%
df = df.dropna()

# %%
df.head()
# Out:
#     obsid          ra       dec         z class   mag1   mag2   mag3   mag4  \
# 0  101001  332.202274 -2.056767 -0.000139  STAR  18.78  17.12  16.42  16.15
# 1  101002  332.471576 -2.085015  0.000119  STAR  20.91  18.10  16.66  16.05
# 2  101005  332.535456 -2.116436 -0.000251  STAR  18.87  17.58  17.00  16.79
# 3  101007  332.512558 -1.841408 -0.000169  STAR  22.89  20.09  18.57  17.35
# 4  101008  332.368745 -1.955771  0.000087  STAR  18.25  16.64  15.97  15.77
#
#     mag5
# 0  15.97
# 1  15.67
# 2  16.64
# 3  16.72
# 4  15.64

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.cosmology import WMAP9 as cosmo

radec = SkyCoord(ra=df['ra']*u.degree, dec=df['dec']*u.degree, frame='icrs')
#radec.ra.value
#radec.dec.value
galactic = radec.galactic

df['l'] = galactic.l.value
df['b'] = galactic.b.value


r = cosmo.comoving_distance(df['z'])
df['distance']= r.value

df.head()
# Out:
#     obsid          ra       dec         z class   mag1   mag2   mag3   mag4  \
# 0  101001  332.202274 -2.056767 -0.000139  STAR  18.78  17.12  16.42  16.15
# 1  101002  332.471576 -2.085015  0.000119  STAR  20.91  18.10  16.66  16.05
# 2  101005  332.535456 -2.116436 -0.000251  STAR  18.87  17.58  17.00  16.79
# 3  101007  332.512558 -1.841408 -0.000169  STAR  22.89  20.09  18.57  17.35
# 4  101008  332.368745 -1.955771  0.000087  STAR  18.25  16.64  15.97  15.77
#
#     mag5          l          b  distance
# 0  15.97  58.660186 -43.716767 -0.599845
# 1  15.67  58.851828 -43.949394  0.515369
# 2  16.64  58.869974 -44.019337 -1.084017
# 3  16.72  59.156336 -43.835957 -0.729873
# 4  15.64  58.910001 -43.789687  0.377950

# %%
df= df.dropna()

# %%
df[['z','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#     class         z
# 2    STAR -0.000207
# 1     QSO  1.590710
# 0  GALAXY  0.143196

# %%
df['class'] = df['class'].astype('category').cat.codes

# %%
y_df = df['class']
columns_titles = ["ra","dec","mag1","mag2","mag4","mag3","mag5","z"]
data=df.reindex(columns=columns_titles)

# %%
data
# Out:
#               ra        dec   mag1   mag2   mag4   mag3   mag5         z
# 0     332.202274  -2.056767  18.78  17.12  16.15  16.42  15.97 -0.000139
# 1     332.471576  -2.085015  20.91  18.10  16.05  16.66  15.67  0.000119
# 2     332.535456  -2.116436  18.87  17.58  16.79  17.00  16.64 -0.000251
# 3     332.512558  -1.841408  22.89  20.09  17.35  18.57  16.72 -0.000169
# 4     332.368745  -1.955771  18.25  16.64  15.77  15.97  15.64  0.000087
# ...          ...        ...    ...    ...    ...    ...    ...       ...
# 9994   80.062085  27.780844  99.00  17.36  16.82  17.00  99.00  0.000335
# 9995   79.883492  27.999486  99.00  16.76  16.34  16.49  99.00  0.000020
# 9997   82.612838  27.981447  99.00  17.93  15.58  16.40  99.00  0.000092
# 9998   82.552755  28.094284  99.00  18.78  17.06  17.61  99.00 -0.000156
# 9999   82.671218  28.006254  99.00  19.25  16.42  17.42  99.00 -0.000125
#
# [8252 rows x 8 columns]

# %%
X_df = data.values

# %%
y_pred = random_forest.predict(X_df)

# %%
Test_acc_random_forest = round(random_forest.score(X_df, y_df) * 100, 3)
print("Accuracy of Random Forest ",Test_acc_random_forest)
# Out:
# Accuracy of Random Forest  91.469

# %%
print(classification_report(y_df, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.03      0.06       678
#            1       0.14      0.99      0.25       112
#            2       1.00      0.99      1.00      7462
#
#     accuracy                           0.91      8252
#    macro avg       0.50      0.67      0.44      8252
# weighted avg       0.94      0.91      0.91      8252

# %%
confusion_matrix(y_df, y_pred)
# Out:
# array([[  23,  655,    0],
#        [   1,  111,    0],
#        [  38,   10, 7414]], dtype=int64)

# %% [markdown]
# # SDSS Test

# %%
df = pd.read_csv('Test/sdss.csv')

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.240000e+18  348.841087  1.268802  25.92735  20.99570  19.24612  18.56461
# 1  1.240000e+18  348.902530  1.271886  19.38905  18.24496  17.58728  17.20807
# 2  1.240000e+18   15.896126  1.264845  20.14134  19.28787  19.04397  18.96897
# 3  1.240000e+18   16.004912  1.259423  21.50923  19.69340  18.47973  17.91998
# 4  1.240000e+18   16.020244  1.267667  20.96947  20.29136  19.36779  18.86387
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  18.43049   94    301       6     93  4.830000e+18  GALAXY  0.399651   4286
# 1  16.90905   94    301       6     94  4.300000e+17  GALAXY  0.032125    382
# 2  18.79573   94    301       6    274  4.460000e+17    STAR -0.000821    396
# 3  17.55132   94    301       6    275  7.540000e+17  GALAXY  0.312048    670
# 4  18.45551   94    301       6    275  7.540000e+17  GALAXY  0.200468    670
#
#      mjd  fiberid
# 0  55499      322
# 1  51816      368
# 2  51816      370
# 3  52520      374
# 4  52520      367

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.cosmology import WMAP9 as cosmo

radec = SkyCoord(ra=df['ra']*u.degree, dec=df['dec']*u.degree, frame='icrs')
#radec.ra.value
#radec.dec.value
galactic = radec.galactic

df['l'] = galactic.l.value
df['b'] = galactic.b.value


r = cosmo.comoving_distance(df['z'])
df['distance']= r.value

df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.240000e+18  348.841087  1.268802  25.92735  20.99570  19.24612  18.56461
# 1  1.240000e+18  348.902530  1.271886  19.38905  18.24496  17.58728  17.20807
# 2  1.240000e+18   15.896126  1.264845  20.14134  19.28787  19.04397  18.96897
# 3  1.240000e+18   16.004912  1.259423  21.50923  19.69340  18.47973  17.91998
# 4  1.240000e+18   16.020244  1.267667  20.96947  20.29136  19.36779  18.86387
#
#           z  run  rerun  ...  field     specobjid   class  redshift  plate  \
# 0  18.43049   94    301  ...     93  4.830000e+18  GALAXY  0.399651   4286
# 1  16.90905   94    301  ...     94  4.300000e+17  GALAXY  0.032125    382
# 2  18.79573   94    301  ...    274  4.460000e+17    STAR -0.000821    396
# 3  17.55132   94    301  ...    275  7.540000e+17  GALAXY  0.312048    670
# 4  18.45551   94    301  ...    275  7.540000e+17  GALAXY  0.200468    670
#
#      mjd  fiberid           l          b      distance
# 0  55499      322   79.914118 -53.382197  10889.870466
# 1  51816      368   79.999146 -53.417022  10737.784722
# 2  51816      370  129.295662 -61.456728  10923.741026
# 3  52520      374  129.523245 -61.451201  10804.270479
# 4  52520      367  129.553380 -61.441430  10892.221138
#
# [5 rows x 21 columns]

# %%
df[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#     class  redshift
# 2    STAR  0.000095
# 1     QSO  1.683068
# 0  GALAXY  0.265592

# %%
def cartesian(dist,alpha,delta):
    x = dist*np.cos(np.deg2rad(delta))*np.cos(np.deg2rad(alpha))
    y = dist*np.cos(np.deg2rad(delta))*np.sin(np.deg2rad(alpha))
    z = dist*np.sin(np.deg2rad(delta))
    return x,y,z

cart = cartesian(df['distance'],df['ra'],df['dec'])
df['x_coord'] = cart[0]
df['y_coord'] = cart[1]
df['z_coord'] = cart[2]

df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.240000e+18  348.841087  1.268802  25.92735  20.99570  19.24612  18.56461
# 1  1.240000e+18  348.902530  1.271886  19.38905  18.24496  17.58728  17.20807
# 2  1.240000e+18   15.896126  1.264845  20.14134  19.28787  19.04397  18.96897
# 3  1.240000e+18   16.004912  1.259423  21.50923  19.69340  18.47973  17.91998
# 4  1.240000e+18   16.020244  1.267667  20.96947  20.29136  19.36779  18.86387
#
#           z  run  rerun  ...  redshift  plate    mjd fiberid           l  \
# 0  18.43049   94    301  ...  0.399651   4286  55499     322   79.914118
# 1  16.90905   94    301  ...  0.032125    382  51816     368   79.999146
# 2  18.79573   94    301  ... -0.000821    396  51816     370  129.295662
# 3  17.55132   94    301  ...  0.312048    670  52520     374  129.523245
# 4  18.45551   94    301  ...  0.200468    670  52520     367  129.553380
#
#            b      distance       x_coord      y_coord     z_coord
# 0 -53.382197  10889.870466  10681.369075 -2107.009227  241.133953
# 1 -53.417022  10737.784722  10534.404562 -2066.284901  238.344241
# 2 -61.456728  10923.741026  10503.455416  2991.220279  241.129770
# 3 -61.451201  10804.270479  10382.967155  2978.231268  237.470296
# 4 -61.441430  10892.221138  10466.651187  3005.266629  240.970378
#
# [5 rows x 24 columns]

# %%
df['u-r'] = df['u']-df['r']

# %%
df = df.dropna()

# %%
df['class']=df['class'].map({'STAR':2,'GALAXY':0,'QSO':1}).astype(int)

# %%
columns_titles = ["ra","dec","u","g","r","i","z","redshift","class"]
data=df.reindex(columns=columns_titles)

# %%
data.head()
# Out:
#            ra       dec         u         g         r         i         z  \
# 0  348.841087  1.268802  25.92735  20.99570  19.24612  18.56461  18.43049
# 1  348.902530  1.271886  19.38905  18.24496  17.58728  17.20807  16.90905
# 2   15.896126  1.264845  20.14134  19.28787  19.04397  18.96897  18.79573
# 3   16.004912  1.259423  21.50923  19.69340  18.47973  17.91998  17.55132
# 4   16.020244  1.267667  20.96947  20.29136  19.36779  18.86387  18.45551
#
#    redshift  class
# 0  0.399651      0
# 1  0.032125      0
# 2 -0.000821      2
# 3  0.312048      0
# 4  0.200468      0

# %%
y_df = data['class']
X_df = data.loc[:, data.columns != 'class'].values

# %%
y_pred = random_forest.predict(X_df)

# %%
Test_acc_random_forest = round(random_forest.score(X_df, y_df) * 100, 3)
print("Accuracy of Random Forest ",Test_acc_random_forest)
# Out:
# Accuracy of Random Forest  43.561

# %% [markdown]
# # 97.72 & 99.7 & 98.994
