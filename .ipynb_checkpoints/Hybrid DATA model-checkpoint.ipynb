# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
import warnings
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import timeit
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('input/SDSS_final.csv')

# %%
df.head()
# Out:
#           objid          ra        dec         u         g         r  \
# 0  1.240000e+18  209.439050  -0.293126  21.40675  20.88552  20.89071
# 1  1.240000e+18  121.877577  45.077250  25.92152  22.26305  20.55681
# 2  1.240000e+18  124.756270  46.143024  22.10301  20.44919  18.64295
# 3  1.240000e+18  183.849461   0.143010  22.85248  22.09973  20.28476
# 4  1.240000e+18  189.810817  -2.207314  20.58849  20.14927  20.02577
#
#           i         z   run  rerun  camcol  field     specobjid   class  \
# 0  20.91209  20.72144   752    301       3    440  4.550000e+18     QSO
# 1  19.71160  19.16875  1331    301       5    126  7.180000e+18  GALAXY
# 2  17.98695  17.58418  1331    301       3    140  4.970000e+17  GALAXY
# 3  19.41890  19.06876   752    301       4    269  4.330000e+18  GALAXY
# 4  20.14147  19.83024  1140    301       4    246  4.250000e+18     QSO
#
#    redshift  plate    mjd  fiberid
# 0  2.399763   4037  55631      474
# 1  0.456324   6378  56330      717
# 2  0.354595    441  51868      115
# 3  0.480464   3845  55323       17
# 4  0.748259   3778  55213      110

# %%
df['class'].value_counts()
# Out:
# GALAXY    10000
# QSO       10000
# STAR      10000
# Name: class, dtype: int64

# %%
df['class'].head(10)
ax = sns.countplot(x='class',data=df)

# %%
df[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#     class  redshift
# 2    STAR  0.000082
# 1     QSO  1.913542
# 0  GALAXY  0.345878

# %% [markdown]
# # Distance

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.cosmology import WMAP9 as cosmo

radec = SkyCoord(ra=df['ra']*u.degree, dec=df['dec']*u.degree, frame='icrs')
#radec.ra.value
#radec.dec.value
galactic = radec.galactic

df['l'] = galactic.l.value
df['b'] = galactic.b.value


r = cosmo.comoving_distance(df['redshift'])
df['distance']= r.value

df
# Out:
#               objid          ra        dec         u         g         r  \
# 0      1.240000e+18  209.439050  -0.293126  21.40675  20.88552  20.89071
# 1      1.240000e+18  121.877577  45.077250  25.92152  22.26305  20.55681
# 2      1.240000e+18  124.756270  46.143024  22.10301  20.44919  18.64295
# 3      1.240000e+18  183.849461   0.143010  22.85248  22.09973  20.28476
# 4      1.240000e+18  189.810817  -2.207314  20.58849  20.14927  20.02577
# ...             ...         ...        ...       ...       ...       ...
# 29995  1.240000e+18  151.201083   0.669279  18.81863  18.52837  18.08999
# 29996  1.240000e+18  188.829694  -1.649740  22.98777  21.13206  21.01412
# 29997  1.240000e+18  217.679029  -0.721670  24.81813  22.65607  21.01129
# 29998  1.240000e+18  160.476541  -0.032671  22.54886  22.03707  20.39451
# 29999  1.240000e+18   55.448055  -5.184580  20.31474  19.48810  18.46058
#
#               i         z   run  rerun  ...  field     specobjid   class  \
# 0      20.91209  20.72144   752    301  ...    440  4.550000e+18     QSO
# 1      19.71160  19.16875  1331    301  ...    126  7.180000e+18  GALAXY
# 2      17.98695  17.58418  1331    301  ...    140  4.970000e+17  GALAXY
# 3      19.41890  19.06876   752    301  ...    269  4.330000e+18  GALAXY
# 4      20.14147  19.83024  1140    301  ...    246  4.250000e+18     QSO
# ...         ...       ...   ...    ...  ...    ...           ...     ...
# 29995  17.74230  17.65442   756    301  ...    236  3.030000e+17     QSO
# 29996  21.17362  21.28052  1231    301  ...    131  4.250000e+18    STAR
# 29997  19.97748  19.63805   752    301  ...    495  4.540000e+18  GALAXY
# 29998  19.32129  18.54318   756    301  ...    298  4.320000e+18  GALAXY
# 29999  18.01105  17.62169  1045    301  ...    144  1.840000e+18  GALAXY
#
#        redshift  plate    mjd  fiberid           l          b     distance
# 0      2.399763   4037  55631      474  335.802303  58.281597  5836.558786
# 1      0.456324   6378  56330      717  174.738198  31.847513  1768.531893
# 2      0.354595    441  51868      115  173.753033  33.970311  1410.377891
# 3      0.480464   3845  55323       17  283.669273  61.659483  1850.531720
# 4      0.748259   3778  55213      110  296.732861  60.517572  2687.230704
# ...         ...    ...    ...      ...         ...        ...          ...
# 29995  0.214063    269  51910      536  239.354367  42.083253   881.491565
# 29996  0.000145   3778  55213      695  294.611002  60.961320     0.625851
# 29997  0.557969   4028  55621        3  347.571462  53.319252  2106.244464
# 29998  0.550828   3834  56014      459  248.683408  48.705166  2083.159184
# 29999  0.293565   1631  54469      448  192.288143 -43.928627  1185.591698
#
# [30000 rows x 21 columns]

# %%
def cartesian(dist,alpha,delta):
    x = dist*np.cos(np.deg2rad(delta))*np.cos(np.deg2rad(alpha))
    y = dist*np.cos(np.deg2rad(delta))*np.sin(np.deg2rad(alpha))
    z = dist*np.sin(np.deg2rad(delta))
    return x,y,z

cart = cartesian(df['distance'],df['ra'],df['dec'])
df['x_coord'] = cart[0]
df['y_coord'] = cart[1]
df['z_coord'] = cart[2]

df.head()
# Out:
#           objid          ra        dec         u         g         r  \
# 0  1.240000e+18  209.439050  -0.293126  21.40675  20.88552  20.89071
# 1  1.240000e+18  121.877577  45.077250  25.92152  22.26305  20.55681
# 2  1.240000e+18  124.756270  46.143024  22.10301  20.44919  18.64295
# 3  1.240000e+18  183.849461   0.143010  22.85248  22.09973  20.28476
# 4  1.240000e+18  189.810817  -2.207314  20.58849  20.14927  20.02577
#
#           i         z   run  rerun  ...  redshift  plate    mjd fiberid  \
# 0  20.91209  20.72144   752    301  ...  2.399763   4037  55631     474
# 1  19.71160  19.16875  1331    301  ...  0.456324   6378  56330     717
# 2  17.98695  17.58418  1331    301  ...  0.354595    441  51868     115
# 3  19.41890  19.06876   752    301  ...  0.480464   3845  55323      17
# 4  20.14147  19.83024  1140    301  ...  0.748259   3778  55213     110
#
#             l          b     distance      x_coord      y_coord      z_coord
# 0  335.802303  58.281597  5836.558786 -5082.870147 -2868.616031   -29.859759
# 1  174.738198  31.847513  1768.531893  -659.527190  1060.499615  1252.225821
# 2  173.753033  33.970311  1410.377891  -557.085975   802.848493  1016.983437
# 3  283.669273  61.659483  1850.531720 -1846.350956  -124.235501     4.618923
# 4  296.732861  60.517572  2687.230704 -2645.967218  -457.552353  -103.499677
#
# [5 rows x 24 columns]

# %%
df['u-r'] = df['u']-df['r']

# %%
df.head()
# Out:
#           objid          ra        dec         u         g         r  \
# 0  1.240000e+18  209.439050  -0.293126  21.40675  20.88552  20.89071
# 1  1.240000e+18  121.877577  45.077250  25.92152  22.26305  20.55681
# 2  1.240000e+18  124.756270  46.143024  22.10301  20.44919  18.64295
# 3  1.240000e+18  183.849461   0.143010  22.85248  22.09973  20.28476
# 4  1.240000e+18  189.810817  -2.207314  20.58849  20.14927  20.02577
#
#           i         z   run  rerun  ...  plate    mjd  fiberid           l  \
# 0  20.91209  20.72144   752    301  ...   4037  55631      474  335.802303
# 1  19.71160  19.16875  1331    301  ...   6378  56330      717  174.738198
# 2  17.98695  17.58418  1331    301  ...    441  51868      115  173.753033
# 3  19.41890  19.06876   752    301  ...   3845  55323       17  283.669273
# 4  20.14147  19.83024  1140    301  ...   3778  55213      110  296.732861
#
#            b     distance      x_coord      y_coord      z_coord      u-r
# 0  58.281597  5836.558786 -5082.870147 -2868.616031   -29.859759  0.51604
# 1  31.847513  1768.531893  -659.527190  1060.499615  1252.225821  5.36471
# 2  33.970311  1410.377891  -557.085975   802.848493  1016.983437  3.46006
# 3  61.659483  1850.531720 -1846.350956  -124.235501     4.618923  2.56772
# 4  60.517572  2687.230704 -2645.967218  -457.552353  -103.499677  0.56272
#
# [5 rows x 25 columns]

# %%
df['class'] = df['class'].astype('category').cat.codes

# %%
df['class'].value_counts()
# Out:
# 0    10000
# 1    10000
# 2    10000
# Name: class, dtype: int64

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid',
#        'l', 'b', 'distance', 'x_coord', 'y_coord', 'z_coord', 'u-r'],
#       dtype='object')

# %%
df[['redshift','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#    class  redshift
# 2      2  0.000082
# 1      1  1.913542
# 0      0  0.345878

# %%
X_df = df.drop(['objid','class','run','rerun','camcol','field','specobjid','plate','mjd','fiberid','ra','dec'], axis=1).values
y_df = df['class'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.30, random_state=44, shuffle =True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
random_forest = RandomForestClassifier(n_estimators=200)

start_time_train = timeit.default_timer()
random_forest.fit(X_train, y_train)
upsampling_elapsed = timeit.default_timer() - start_time_train
print('Training time for RBF: ' + str(upsampling_elapsed))
# Out:
# Training time for RBF: 9.768938799999887

# %%
y_pred = random_forest.predict(X_test)

Test_acc_random_forest = round(random_forest.score(X_test, y_test) * 100, 3)
print("Accuracy of Random Forest ",Test_acc_random_forest)
# Out:
# Accuracy of Random Forest  98.044

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      2965
#            1       0.98      0.96      0.97      2951
#            2       1.00      1.00      1.00      3084
#
#     accuracy                           0.98      9000
#    macro avg       0.98      0.98      0.98      9000
# weighted avg       0.98      0.98      0.98      9000

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[2908,   54,    3],
#        [ 114, 2832,    5],
#        [   0,    0, 3084]], dtype=int64)

# %% [markdown]
# # Lamost Test

# %%
df = pd.read_csv('Test/40879.csv')

# %%
df = df.dropna()

# %%
df.head()
# Out:
#     obsid          ra       dec         z class   mag1   mag2   mag3   mag4  \
# 0  101001  332.202274 -2.056767 -0.000139  STAR  18.78  17.12  16.42  16.15
# 1  101002  332.471576 -2.085015  0.000119  STAR  20.91  18.10  16.66  16.05
# 2  101005  332.535456 -2.116436 -0.000251  STAR  18.87  17.58  17.00  16.79
# 3  101007  332.512558 -1.841408 -0.000169  STAR  22.89  20.09  18.57  17.35
# 4  101008  332.368745 -1.955771  0.000087  STAR  18.25  16.64  15.97  15.77
#
#     mag5
# 0  15.97
# 1  15.67
# 2  16.64
# 3  16.72
# 4  15.64

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.cosmology import WMAP9 as cosmo

radec = SkyCoord(ra=df['ra']*u.degree, dec=df['dec']*u.degree, frame='icrs')
#radec.ra.value
#radec.dec.value
galactic = radec.galactic

df['l'] = galactic.l.value
df['b'] = galactic.b.value


r = cosmo.comoving_distance(df['z'])
df['distance']= r.value

df.head()
# Out:
#     obsid          ra       dec         z class   mag1   mag2   mag3   mag4  \
# 0  101001  332.202274 -2.056767 -0.000139  STAR  18.78  17.12  16.42  16.15
# 1  101002  332.471576 -2.085015  0.000119  STAR  20.91  18.10  16.66  16.05
# 2  101005  332.535456 -2.116436 -0.000251  STAR  18.87  17.58  17.00  16.79
# 3  101007  332.512558 -1.841408 -0.000169  STAR  22.89  20.09  18.57  17.35
# 4  101008  332.368745 -1.955771  0.000087  STAR  18.25  16.64  15.97  15.77
#
#     mag5          l          b  distance
# 0  15.97  58.660186 -43.716767 -0.599845
# 1  15.67  58.851828 -43.949394  0.515369
# 2  16.64  58.869974 -44.019337 -1.084017
# 3  16.72  59.156336 -43.835957 -0.729873
# 4  15.64  58.910001 -43.789687  0.377950

# %%
df= df.dropna()

# %%
df[['z','class']].groupby(['class'],as_index=False).mean().sort_values(by='class',ascending=False)
# Out:
#     class         z
# 2    STAR -0.000207
# 1     QSO  1.590710
# 0  GALAXY  0.143196

# %%
def cartesian(dist,alpha,delta):
    x = dist*np.cos(np.deg2rad(delta))*np.cos(np.deg2rad(alpha))
    y = dist*np.cos(np.deg2rad(delta))*np.sin(np.deg2rad(alpha))
    z = dist*np.sin(np.deg2rad(delta))
    return x,y,z

cart = cartesian(df['distance'],df['ra'],df['dec'])
df['x_coord'] = cart[0]
df['y_coord'] = cart[1]
df['z_coord'] = cart[2]

df.head()
# Out:
#     obsid          ra       dec         z class   mag1   mag2   mag3   mag4  \
# 0  101001  332.202274 -2.056767 -0.000139  STAR  18.78  17.12  16.42  16.15
# 1  101002  332.471576 -2.085015  0.000119  STAR  20.91  18.10  16.66  16.05
# 2  101005  332.535456 -2.116436 -0.000251  STAR  18.87  17.58  17.00  16.79
# 3  101007  332.512558 -1.841408 -0.000169  STAR  22.89  20.09  18.57  17.35
# 4  101008  332.368745 -1.955771  0.000087  STAR  18.25  16.64  15.97  15.77
#
#     mag5          l          b  distance   x_coord   y_coord   z_coord
# 0  15.97  58.660186 -43.716767 -0.599845 -0.530281  0.279558  0.021528
# 1  15.67  58.851828 -43.949394  0.515369  0.456717 -0.238040 -0.018750
# 2  16.64  58.869974 -44.019337 -1.084017 -0.961188  0.499607  0.040033
# 3  16.72  59.156336 -43.835957 -0.729873 -0.647145  0.336702  0.023453
# 4  15.64  58.910001 -43.789687  0.377950  0.334650 -0.175183 -0.012899

# %%
df['u-r'] = df['mag1']-df['mag4']

# %%
df['class'] = df['class'].astype('category').cat.codes

# %%
y_df = df['class']

# %%
columns_titles = ["mag1","mag2","mag4","mag3","mag5","z","l","b","distance","x_coord","y_coord","z_coord","u-r"]
data=df.reindex(columns=columns_titles)

# %%
X_df = data.values

# %%
y_pred = random_forest.predict(X_df)

# %%
Test_acc_random_forest = round(random_forest.score(X_df, y_df) * 100, 3)
print("Accuracy of Random Forest ",Test_acc_random_forest)
# Out:
# Accuracy of Random Forest  99.927

# %%
print(classification_report(y_df, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       678
#            1       0.98      0.96      0.97       112
#            2       1.00      1.00      1.00      7462
#
#     accuracy                           1.00      8252
#    macro avg       0.99      0.99      0.99      8252
# weighted avg       1.00      1.00      1.00      8252

# %%
confusion_matrix(y_df, y_pred)
# Out:
# array([[ 676,    2,    0],
#        [   4,  108,    0],
#        [   0,    0, 7462]], dtype=int64)
